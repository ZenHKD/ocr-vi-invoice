# %% [markdown]
# # U-2- (Salient Object Detection)
# Pre-trained model to remove background

# %%
# %run scanner.py --input ../../data/test/mcocr_val_145114anqqj.jpg
# Out:
# Processing ../../data/test/mcocr_val_145114anqqj.jpg with Deep Learning (rembg)...
