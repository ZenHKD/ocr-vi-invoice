# %% [markdown]
# # Full OCR Pipeline

# %%
# %run pipeline.py --image_path "../../data/vinh/632606273_909855034867069_1845697813161061576_n.jpg" --det_model ../../weights/det/best_model.pth --rec_model ../../weights/rec_finetune/best_model.pth --visualize --visualize_crops --preprocess
# Out:
# Using device: cuda
# Loading detection model from ../../weights/det/best_model.pth...
# Loading recognition model from ../../weights/rec_finetune/best_model.pth...
# Found 1 images to process
#
# Processing: 632606273_909855034867069_1845697813161061576_n.jpg
# ...
#   [1/4] Running U^2-Net Document Scanner preprocessing...
#         Preprocessing complete.
#   [2/4] Running text detection...
#         Detected 55 text regions
#   [3/4] Running text recognition on crops...
#         Region 1: '834,000'
#         Region 2: 'Khách phải trả'
#         Region 3: '5000'
#         Region 4: 'PN gac hảng'
#         Region 5: '818203'
#         Region 6: 'Tổng Tên'
#         Region 7: 'anh Hiểều ds'
#         Region 8: '8'
#         Region 9: 'Tổng ó ơng'
#         Region 10: ''
#         Region 11: '4'
#         Region 12: '169000'
#         Region 13: '169000'
#         Region 14: '1'
#         Region 15: 'Con'
#         Region 16: 'ịGa 0 Muổi Hoa Têu'
#         Region 17: '3'
# ...
