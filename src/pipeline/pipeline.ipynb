# %% [markdown]
# # Full OCR Pipeline

# %%
# %run pipeline.py --image_path ../../data/test/mcocr_val_145114anqqj.jpg --det_model ../../weights/det/best_model.pth --rec_model ../../weights/rec/best_model.pth --visualize --visualize_crops --preprocess
