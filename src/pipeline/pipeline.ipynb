# %% [markdown]
# # Full OCR Pipeline

# %%
# %run pipeline2.py --image_path "../../data/test/mcocr_val_145114aszbc.jpg" --det_model ../../weights/det/best_model.pth --rec_model ../../weights/rec2_aug/best_model.pth --visualize --visualize_crops --preprocess
# Out:
# Using device: cuda
# Loading detection model: ../../weights/det/best_model.pth
# Loading recognition model: ../../weights/rec2_aug/best_model.pth
#   SVTRv2-base loaded (epoch 11, best_acc=0.2980132450331126)
# Found 1 images to process
#
# Processing: mcocr_val_145114aszbc.jpg
# ...
#   [1/4] Running Document Scanner preprocessing...
#         Done.
#   [2/4] Running text detection...
#         Detected 34 text regions
#   [3/4] Running SVTRv2 recognition (34 crops)...
#         Region 1: 'Hotline: 02471066866 Website: Vinmart.com'
#         Region 2: 'CÁM ƠN QUÝ KHÁCH VÀ HẸN GẶP LẠI'
#         Region 3: 'tax invoice will be issued within same day'
#         Region 4: 'Chỉ xuất hóa đơn trong ngày'
#         Region 5: '(Giá đã bao gồm thuế GTGT)'
#         Region 6: '0'
#         Region 7: 'TIỀN TRÀ LẠI'
#         Region 8: '22.000'
#         Region 9: 'TIỀN MẶT'
#         Region 10: '22.000'
#         Region 11: 'TIỀN KHÁCH TRÀ'
#         Region 12: 'O'
# ...
